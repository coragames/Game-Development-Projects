# %%
pip install PyOpenGL PyOpenGL_accelerate
# Out:
# ...
#   Installing build dependencidone
#   Getting requirements to build wheel ... one
#   Preparing metadata (pyproject.toml) ... one
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 25.4 MB/s eta 0:00:00
# ...
#   Created wheel for PyOpenGL_accelerate: filename=pyopengl_accelerate-3.1.10-cp313-cp313-macosx_10_15_x86_64.whl size=383106 sha256=3269e7acb34bb175f2d2cf5d329a372ca011464217148875c38eee699db377f5
#   Stored in directory: /Users/ravirajpanchal/Library/Caches/pip/wheels/5e/51/94/7f45a6b92bcff048c33ab6265cb335f107d7e03ef3fba56e9c
# Successfully built PyOpenGL_accelerate
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [PyOpenGL]1/2 [PyOpenGL]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import OpenGL
